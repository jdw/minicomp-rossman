# %%
import joblib
import sklearn.ensemble as se

# %%
data = joblib.load("../../data/processed/clean_data.joblib")

# %%
data["Sales"]
# Out:
# Date
# 2013-01-02     3697.0
# 2013-01-03     4297.0
# 2013-01-04     4540.0
# 2013-01-05     4771.0
# 2013-01-07     6905.0
#                ...
# 2014-06-25     3575.0
# 2014-06-26     3335.0
# 2014-06-27     4724.0
# 2014-06-28     5398.0
# 2014-06-30    12410.0
# Name: Sales, Length: 497376, dtype: float64

# %%
map_outlier = se.IsolationForest().fit_predict(data[["Sales", "CompetitionDistance", "aggregated_promo2", "days_since_competition"]])

# %%
data[map_outlier == 1]
# Out:
#              Store  DayOfWeek   Sales  Promo StateHoliday  SchoolHoliday  \
# Date
# 2013-01-02  1115.0        3.0  3697.0    0.0            0            1.0
# 2013-01-03  1115.0        4.0  4297.0    0.0            0            1.0
# 2013-01-04  1115.0        5.0  4540.0    0.0            0            1.0
# 2013-01-05  1115.0        6.0  4771.0    0.0            0            1.0
# 2013-01-07  1115.0        1.0  6905.0    1.0            0            1.0
# ...            ...        ...     ...    ...          ...            ...
# 2014-04-12   127.0        6.0  5230.0    0.0            0            0.0
# 2014-04-15   127.0        2.0  6705.0    1.0            0            1.0
# 2014-04-16   127.0        3.0  7278.0    1.0            0            1.0
# 2014-04-17   127.0        4.0  7237.0    1.0            0            1.0
# 2014-04-19   127.0        6.0  6222.0    0.0            0            0.0
#
#            StoreType Assortment  CompetitionDistance     PromoInterval  Year  \
# ...

# %%
data
# Out:
#              Store  DayOfWeek    Sales  Promo StateHoliday  SchoolHoliday  \
# Date
# 2013-01-02  1115.0        3.0   3697.0    0.0            0            1.0
# 2013-01-03  1115.0        4.0   4297.0    0.0            0            1.0
# 2013-01-04  1115.0        5.0   4540.0    0.0            0            1.0
# 2013-01-05  1115.0        6.0   4771.0    0.0            0            1.0
# 2013-01-07  1115.0        1.0   6905.0    1.0            0            1.0
# ...            ...        ...      ...    ...          ...            ...
# 2014-06-25   127.0        3.0   3575.0    0.0            0            0.0
# 2014-06-26   127.0        4.0   3335.0    0.0            0            0.0
# 2014-06-27   127.0        5.0   4724.0    0.0            0            0.0
# 2014-06-28   127.0        6.0   5398.0    0.0            0            0.0
# 2014-06-30   127.0        1.0  12410.0    1.0            0            0.0
#
# ...
